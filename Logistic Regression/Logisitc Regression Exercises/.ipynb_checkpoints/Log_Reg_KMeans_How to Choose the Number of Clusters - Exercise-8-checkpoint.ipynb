# %% [markdown]
# # How to Choose the Number of Clusters

# %% [markdown]
# Using the same code as in the previous exercise, find the WCSS for clustering solutions with 1 to 10 clusters (you can try with more if you wish).
#
# Find the most suitable solutions, run them and compare the results.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries-exercise.csv'</i>.

# %%
# Load the data
raw_data = pd.read_csv('Countries-exercise.csv')
# Check the data
raw_data.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
data = raw_data.copy()

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Make sure to select the appropriate features since we are no longer using the categorical variable for our clustering but rather <i>'Longitude'</i> and <i>'Laditude'</i>.

# %%
x = data.iloc[:,1:3]
x.head()
# Out:
#    Longitude   Latitude
# 0 -69.982677  12.520880
# 1  66.004734  33.835231
# 2  17.537368 -12.293361
# 3 -63.064989  18.223959
# 4  20.049834  41.142450

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
kmeans=KMeans(10)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Clustering results

# %%
identified_clusters = kmeans.fit_predict(x)
#identified_clusters

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
#data_with_clusters

# %% [markdown]
# Plot the data once again but separate the data by the clusters we defined.

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data['Longitude'], data['Latitude'],c=data_with_clusters['Cluster'], cmap = 'rainbow')
plt.title('10 Clusters')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %% [markdown]
# Use the ingerated <i>sklearn</i> method <i> 'inertia_' </i>.

# %%
kmeans.inertia_
# Out:
# 256595.22356029783

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
wcss=[]

for i in range(1,11):
    kmeans=KMeans(i)
    kmeans.fit(x) #fit te input data x, using kmeans
    wcss_iter=kmeans.inertia_
    wcss.append(wcss_iter)

# %%
wcss
# Out:
# [1413859.6798344273,
#  657012.0797586325,
#  325235.522370559,
#  256590.585754061,
#  192194.9829002524,
#  154934.51021559333,
#  127549.3139416837,
#  102891.39703473676,
#  84927.05022223276,
#  76499.77258640353]

# %% [markdown]
# ### The Elbow Method

# %%
number_cluster=range(1,11)
plt.plot(number_cluster,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Cluster')
plt.ylabel('WCSS values')
#plt.plot(x,y)
# Out:
# Text(0,0.5,'WCSS values')

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %% [markdown]
# ---
# ### Resulting Scatter Plots:
#
# 4 Clusters:
# ![Exercise_8-4%20Clusters.png](attachment:Exercise_8-4%20Clusters.png)
# 5 Clusters:
# ![Exercise_8-5%20Clusters.png](attachment:Exercise_8-5%20Clusters.png)
# 6 Clusters:
# ![Exercise_8-6%20Clusters.png](attachment:Exercise_8-6%20Clusters.png)
# 7 Clusters:
# ![Exercise_8-7%20Clusters.png](attachment:Exercise_8-7%20Clusters.png)
# 8 Clusters:
# ![Exercise_8-8%20Clusters.png](attachment:Exercise_8-8%20Clusters.png)
# 9 Clusters:
# ![Exercise_8-9%20Clusters.png](attachment:Exercise_8-9%20Clusters.png)
# 10 Clusters:
# ![Exercise_8-10%20Clusters.png](attachment:Exercise_8-10%20Clusters.png)
